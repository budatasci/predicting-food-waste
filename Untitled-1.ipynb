# %%
# reading csv files

import os
import glob
import pandas as pd

class ReadCSV:
    def __init__(self, parent_dir):
        self.parent_dir = parent_dir
        os.chdir(parent_dir)
        self.folder = os.path.join(self.parent_dir) # folder where data retrieve are stored

    def list_of_dfs(self): 
        dfs = []
        for file_name in glob.glob('*.csv'):
            x = pd.read_csv(file_name)
            dfs.append(x)
        return dfs #list of csvs

    def merge_dfs(self):
        dfs = self.list_of_dfs()

# %%
class Main:
    def __init__(self):
        return
        
    def get_data(self, parentdir):
        csvs = ReadCSV(parentdir)
        return csvs.list_of_dfs()

main = Main()
csvs = main.get_data("/Users/rebecca/predicting-food-waste/data")
#len(csvs) #list of csvs
csvs[0].head()
# Out:
#   Daily Run Sheet - GSU  -  9/1/2022 to 9/30/2022   Unnamed: 1     Unnamed: 2  \
# 0                                        Event ID  Guest Count  Building Room
# 1                                          143732            1            GSU
# 2                                          143733            1            GSU
# 3                                          143734            1            GSU
# 4                                          143735            1            GSU
#
#        Unnamed: 3    Unnamed: 4 Unnamed: 5        Unnamed: 6 Unnamed: 7  \
# 0  Street Address  SuppliesTime  Food Time  Event Start Time   End Time
# 1    775 Comm Ave       6:30 AM    6:30 AM           6:30 AM    6:30 AM
# 2    775 Comm Ave       6:30 AM    6:30 AM           6:30 AM    6:30 AM
# 3    775 Comm Ave       6:30 AM    6:30 AM           6:30 AM    6:30 AM
# 4    775 Comm Ave       6:30 AM    6:30 AM           6:30 AM    6:30 AM
#
#   Unnamed: 8    Unnamed: 9      Unnamed: 10    Unnamed: 11 Unnamed: 12
# 0       Tier  Drop Steward  Pick Up Steward  Event Manager      Select
# 1          1          Luis           NO P/U            NaN         NaN
# 2          1       Antonio           NO P/U            NaN         NaN
# 3          1          Luis           NO P/U            NaN         NaN
# 4          1          Luis           NO P/U            NaN         NaN
